# %%
import torch
import torch.nn as nn
from transformers import AutoTokenizer, AutoModelForCausalLM, AutoConfig

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#tokenizer.pre_tokenizer = Whitespace()
tokenizer = AutoTokenizer.from_pretrained(
    "meta-llama/Llama-2-7b-chat-hf",
    cache_dir="D:/Models",)

model = AutoModelForCausalLM.from_pretrained(
    "meta-llama/Llama-2-7b-chat-hf",
    cache_dir="D:/Models",
    device_map='auto',
    offload_folder="D:/Models")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:root:Some parameters are on the meta device device because they were offloaded to the disk and cpu.

# %%
def get_llama2_reponse(prompt, max_new_tokens=50):
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    outputs = model.generate(**inputs, max_new_tokens=max_new_tokens, temperature= 0.00001)
    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response

# %%
prompt = "She is"
get_llama2_reponse(prompt, max_new_tokens=50)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 prompt = "She is"
# ----> 2 get_llama2_reponse(prompt, max_new_tokens=50)
#
# Cell In[2], line 3, in get_llama2_reponse(prompt, max_new_tokens)
#       1 def get_llama2_reponse(prompt, max_new_tokens=50):
#       2     inputs = tokenizer(prompt, return_tensors="pt").to(device)
# ----> 3     outputs = model.generate(**inputs, max_new_tokens=max_new_tokens, temperature= 0.00001)
#       4     response = tokenizer.decode(outputs[0], skip_special_tokens=True)
#       5     return response
#
# File ~\anaconda3\Lib\site-packages\torch\utils\_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\transformers\generation\utils.py:1575, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1567     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1568         input_ids=input_ids,
#    1569         expand_size=generation_config.num_return_sequences,
#    1570         is_encoder_decoder=self.config.is_encoder_decoder,
#    1571         **model_kwargs,
#    1572     )
#    1574     # 13. run sample
# -> 1575     result = self._sample(
#    1576         input_ids,
#    1577         logits_processor=prepared_logits_processor,
#    1578         logits_warper=logits_warper,
#    1579         stopping_criteria=prepared_stopping_criteria,
#    1580         pad_token_id=generation_config.pad_token_id,
#    1581         eos_token_id=generation_config.eos_token_id,
#    1582         output_scores=generation_config.output_scores,
#    1583         output_logits=generation_config.output_logits,
#    1584         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1585         synced_gpus=synced_gpus,
#    1586         streamer=streamer,
#    1587         **model_kwargs,
#    1588     )
#    1590 elif generation_mode == GenerationMode.BEAM_SEARCH:
#    1591     # 11. prepare beam search scorer
#    1592     beam_scorer = BeamSearchScorer(
#    1593         batch_size=batch_size,
#    1594         num_beams=generation_config.num_beams,
#    (...)
#    1599         max_length=generation_config.max_length,
#    1600     )
#
# File ~\anaconda3\Lib\site-packages\transformers\generation\utils.py:2697, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, logits_warper, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, output_logits, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2694 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2696 # forward pass to get next token
# -> 2697 outputs = self(
#    2698     **model_inputs,
#    2699     return_dict=True,
#    2700     output_attentions=output_attentions,
#    2701     output_hidden_states=output_hidden_states,
#    2702 )
#    2704 if synced_gpus and this_peer_finished:
#    2705     continue  # don't waste resources running the code we don't need
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\anaconda3\Lib\site-packages\accelerate\hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File ~\anaconda3\Lib\site-packages\transformers\models\llama\modeling_llama.py:1196, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1193 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1195 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1196 outputs = self.model(
#    1197     input_ids=input_ids,
#    1198     attention_mask=attention_mask,
#    1199     position_ids=position_ids,
#    1200     past_key_values=past_key_values,
#    1201     inputs_embeds=inputs_embeds,
#    1202     use_cache=use_cache,
#    1203     output_attentions=output_attentions,
#    1204     output_hidden_states=output_hidden_states,
#    1205     return_dict=return_dict,
#    1206     cache_position=cache_position,
#    1207 )
#    1209 hidden_states = outputs[0]
#    1210 if self.config.pretraining_tp > 1:
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\anaconda3\Lib\site-packages\transformers\models\llama\modeling_llama.py:1016, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1005     layer_outputs = self._gradient_checkpointing_func(
#    1006         decoder_layer.__call__,
#    1007         hidden_states,
#    (...)
#    1013         cache_position,
#    1014     )
#    1015 else:
# -> 1016     layer_outputs = decoder_layer(
#    1017         hidden_states,
#    1018         attention_mask=causal_mask,
#    1019         position_ids=position_ids,
#    1020         past_key_value=past_key_values,
#    1021         output_attentions=output_attentions,
#    1022         use_cache=use_cache,
#    1023         cache_position=cache_position,
#    1024     )
#    1026 hidden_states = layer_outputs[0]
#    1028 if use_cache:
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\anaconda3\Lib\site-packages\accelerate\hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File ~\anaconda3\Lib\site-packages\transformers\models\llama\modeling_llama.py:754, in LlamaDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, **kwargs)
#     752 residual = hidden_states
#     753 hidden_states = self.post_attention_layernorm(hidden_states)
# --> 754 hidden_states = self.mlp(hidden_states)
#     755 hidden_states = residual + hidden_states
#     757 outputs = (hidden_states,)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\anaconda3\Lib\site-packages\accelerate\hooks.py:166, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     164         output = module._old_forward(*args, **kwargs)
#     165 else:
# --> 166     output = module._old_forward(*args, **kwargs)
#     167 return module._hf_hook.post_forward(module, output)
#
# File ~\anaconda3\Lib\site-packages\transformers\models\llama\modeling_llama.py:240, in LlamaMLP.forward(self, x)
#     238     down_proj = sum(down_proj)
#     239 else:
# --> 240     down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#     242 return down_proj
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~\anaconda3\Lib\site-packages\accelerate\hooks.py:161, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     160 def new_forward(module, *args, **kwargs):
# --> 161     args, kwargs = module._hf_hook.pre_forward(module, *args, **kwargs)
#     162     if module._hf_hook.no_grad:
#     163         with torch.no_grad():
#
# File ~\anaconda3\Lib\site-packages\accelerate\hooks.py:328, in AlignDevicesHook.pre_forward(self, module, *args, **kwargs)
#     321 for name, _ in named_module_tensors(
#     322     module,
#     323     include_buffers=self.offload_buffers,
#     324     recurse=self.place_submodules,
#     325     remove_non_persistent=True,
#     326 ):
#     327     fp16_statistics = None
# --> 328     value = self.weights_map[name]
#     329     if "weight" in name and name.replace("weight", "SCB") in self.weights_map.keys():
#     330         if value.dtype == torch.int8:
#
# File ~\anaconda3\Lib\site-packages\accelerate\utils\offload.py:118, in PrefixedDataset.__getitem__(self, key)
#     117 def __getitem__(self, key):
# --> 118     return self.dataset[f"{self.prefix}{key}"]
#
# File ~\anaconda3\Lib\site-packages\accelerate\utils\offload.py:178, in OffloadedWeightsLoader.__getitem__(self, key)
#     175         tensor = f.get_tensor(weight_info.get("weight_name", key))
#     177 if "dtype" in weight_info:
# --> 178     tensor = tensor.to(getattr(torch, weight_info["dtype"]))
#     180 if tensor.device != torch.device(device):
#     181     tensor = tensor.to(device)
#
# KeyboardInterrupt:
